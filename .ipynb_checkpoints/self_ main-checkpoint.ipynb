# %%
import pandas as pd

# %%
txt_dir = r"C:\Users\admin\Desktop\github repos\Textual-analysis\sample.txt"
txt = pd.read_csv(r"C:\Users\admin\Desktop\github repos\Textual-analysis\sample.txt" , delimiter="\t")
print(txt)
# Out:
#    Paris Olympics 2024 LIVE Updates: On the 14th day of the Paris Olympics 2024, Wrestler Aman Sehrawat on 9 August defeated Puerto Rico's Darian Toi Cruz in Men’s freestyle 57kg category to bring India's 5th bronze medal. This is also the first wrestling medal for India in the Paris Olympics 2024.
# 0   With this, India's medal tally rose to 6, incl...
# 1   Also, the Indian athletics campaign ended as t...
# 2   Among other details, the Court of Arbitration ...
# 3   Earlier on 8 August, Neeraj Chopra surpassed h...
# 4   Neeraj Chopra threw 1.87m farther than his Tok...
# 5   Catch all the LIVE updates on Paris Olympics 2...
# 6                        09 Aug 2024, 11:25:01 PM IST
# 7   Paris Olympics 2024 LIVE: Aman Sehrawat brings...
# 8   Paris Olympics 2024 LIVE: Wrestler Aman Sehraw...
# 9   Aman Sehrawat dominated from the very beginnin...
# 10  In the second round, Aman continued to dominat...

# %%
from collections import Counter

# %%
with open('sample.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# Tokenize by words
words = text.split()

# Print the tokenized words
print(words)
# Out:
# ['Paris', 'Olympics', '2024', 'LIVE', 'Updates:', 'On', 'the', '14th', 'day', 'of', 'the', 'Paris', 'Olympics', '2024,', 'Wrestler', 'Aman', 'Sehrawat', 'on', '9', 'August', 'defeated', 'Puerto', "Rico's", 'Darian', 'Toi', 'Cruz', 'in', 'Men’s', 'freestyle', '57kg', 'category', 'to', 'bring', "India's", '5th', 'bronze', 'medal.', 'This', 'is', 'also', 'the', 'first', 'wrestling', 'medal', 'for', 'India', 'in', 'the', 'Paris', 'Olympics', '2024.', 'With', 'this,', "India's", 'medal', 'tally', 'rose', 'to', '6,', 'including', '5', 'bronze', 'and', 'one', 'silver.', 'Also,', 'the', 'Indian', 'athletics', 'campaign', 'ended', 'as', 'the', "men's", '4x400', 'm', 'relay', 'race', 'team', 'fell', 'just', 'short', 'of', 'reaching', 'the', 'medal', 'round', 'and', 'finished', 'fifth', 'and', '11th', 'overall', 'in', 'the', 'qualification', 'round', 'on', 'Friday.', 'Among', 'other', 'details,', 'the', 'Court', 'of', 'Arbitration', 'for', 'Sports', 'on', '9', 'August', 'said', 'that', 'the', 'decision', 'on', 'Vinesh', "Phogat's", 'plea', 'against', 'her', 'disqualification', 'over', 'weight', 'issues', 'is', 'expected', 'to', 'be', 'issued', 'before', 'the', 'end', 'of', 'the', 'Olympic', 'Games.', 'Earlier', 'on', '8', 'August,', 'Neeraj', 'Chopra', 'surpassed', 'his', 'gold-medal', 'throw', 'from', 'Tokyo', 'but', 'missed', 'out', 'on', 'a', 'second', 'consecutive', 'top', 'finish', 'due', 'to', 'an', 'exceptional', 'performance', 'by', "Pakistan's", 'Arshad', 'Nadeem.', 'The', 'Indian', "men's", 'hockey', 'team', 'gave', 'PR', 'Sreejesh', 'a', 'storybook', 'ending', 'to', 'his', 'career.', 'He', 'retired', 'with', 'two', 'consecutive', 'Olympic', 'medals', 'after', 'starting', 'his', 'international', 'journey', 'when', 'India', 'first', 'failed', 'to', 'qualify', 'for', 'the', 'Games.', 'Neeraj', 'Chopra', 'threw', '1.87m', 'farther', 'than', 'his', 'Tokyo', 'Olympic', 'gold-winning', 'throw,', 'but', 'in', 'Paris,', 'he', 'secured', 'silver', 'as', 'Arshad', 'Nadeem', 'made', 'history', 'for', 'Pakistan', 'with', 'an', 'Olympic', 'record', 'throw', 'of', '92.97m,', 'crossing', '90m', 'again', 'with', 'his', 'final', 'attempt', 'to', 'claim', 'gold.', 'Nadeem', 'is', 'the', 'first', 'Pakistani', 'to', 'win', 'an', 'individual', 'Olympic', 'gold.', 'Neeraj', 'becomes', 'the', 'third', 'Indian,', 'after', 'PV', 'Sindhu', 'and', 'Sushil', 'Kumar,', 'to', 'win', 'individual', 'Olympic', 'medals', 'at', 'two', 'different', 'Games.', 'Catch', 'all', 'the', 'LIVE', 'updates', 'on', 'Paris', 'Olympics', '2024', 'here,', '09', 'Aug', '2024,', '11:25:01', 'PM', 'IST', 'Paris', 'Olympics', '2024', 'LIVE:', 'Aman', 'Sehrawat', 'brings', '5th', 'bronze', 'medal', 'for', 'India,', '1st', 'in', 'wrestling', 'Paris', 'Olympics', '2024', 'LIVE:', 'Wrestler', 'Aman', 'Sehrawat', 'on', '9', 'August', 'defeated', 'Puerto', "Rico's", 'Darian', 'Toi', 'Cruz', 'in', 'Men’s', 'freestyle', '57kg', 'category', 'to', 'bring', "India's", '5th', 'bronze', 'medal.', 'This', 'is', 'also', 'the', 'first', 'wrestling', 'medal', 'for', 'India', 'in', 'the', 'Paris', 'Olympics', '2024.', 'With', 'this,', "India's", 'medal', 'tally', 'rose', 'to', '6,', 'including', '5', 'bronze', 'and', 'one', 'silver.', 'Aman', 'Sehrawat', 'dominated', 'from', 'the', 'very', 'beginning', 'of', 'the', 'game', 'and', 'kept', 'the', 'lead', 'of', '6-3', 'in', 'the', 'first', 'round.', 'In', 'the', 'second', 'round,', 'Aman', 'continued', 'to', 'dominate', 'over', 'Cruz', 'as', 'he', 'exceed', 'his', 'points', 'to', '13,', 'while', 'Cruz', 'could', 'only', 'win', '5', 'points.']

# %%
len(words)
# Out:
# 404

# %%
from nltk.corpus import stopwords
from string import punctuation

# %%
stop = stopwords.words("english")

# %%
stop_words = list(punctuation)  + stop

# %%
cleaned_txt = []
for i in words:
    if i not in stop_words:
        cleaned_txt.append(i)
print(cleaned_txt)
# Out:
# ['Paris', 'Olympics', '2024', 'LIVE', 'Updates:', 'On', '14th', 'day', 'Paris', 'Olympics', '2024,', 'Wrestler', 'Aman', 'Sehrawat', '9', 'August', 'defeated', 'Puerto', "Rico's", 'Darian', 'Toi', 'Cruz', 'Men’s', 'freestyle', '57kg', 'category', 'bring', "India's", '5th', 'bronze', 'medal.', 'This', 'also', 'first', 'wrestling', 'medal', 'India', 'Paris', 'Olympics', '2024.', 'With', 'this,', "India's", 'medal', 'tally', 'rose', '6,', 'including', '5', 'bronze', 'one', 'silver.', 'Also,', 'Indian', 'athletics', 'campaign', 'ended', "men's", '4x400', 'relay', 'race', 'team', 'fell', 'short', 'reaching', 'medal', 'round', 'finished', 'fifth', '11th', 'overall', 'qualification', 'round', 'Friday.', 'Among', 'details,', 'Court', 'Arbitration', 'Sports', '9', 'August', 'said', 'decision', 'Vinesh', "Phogat's", 'plea', 'disqualification', 'weight', 'issues', 'expected', 'issued', 'end', 'Olympic', 'Games.', 'Earlier', '8', 'August,', 'Neeraj', 'Chopra', 'surpassed', 'gold-medal', 'throw', 'Tokyo', 'missed', 'second', 'consecutive', 'top', 'finish', 'due', 'exceptional', 'performance', "Pakistan's", 'Arshad', 'Nadeem.', 'The', 'Indian', "men's", 'hockey', 'team', 'gave', 'PR', 'Sreejesh', 'storybook', 'ending', 'career.', 'He', 'retired', 'two', 'consecutive', 'Olympic', 'medals', 'starting', 'international', 'journey', 'India', 'first', 'failed', 'qualify', 'Games.', 'Neeraj', 'Chopra', 'threw', '1.87m', 'farther', 'Tokyo', 'Olympic', 'gold-winning', 'throw,', 'Paris,', 'secured', 'silver', 'Arshad', 'Nadeem', 'made', 'history', 'Pakistan', 'Olympic', 'record', 'throw', '92.97m,', 'crossing', '90m', 'final', 'attempt', 'claim', 'gold.', 'Nadeem', 'first', 'Pakistani', 'win', 'individual', 'Olympic', 'gold.', 'Neeraj', 'becomes', 'third', 'Indian,', 'PV', 'Sindhu', 'Sushil', 'Kumar,', 'win', 'individual', 'Olympic', 'medals', 'two', 'different', 'Games.', 'Catch', 'LIVE', 'updates', 'Paris', 'Olympics', '2024', 'here,', '09', 'Aug', '2024,', '11:25:01', 'PM', 'IST', 'Paris', 'Olympics', '2024', 'LIVE:', 'Aman', 'Sehrawat', 'brings', '5th', 'bronze', 'medal', 'India,', '1st', 'wrestling', 'Paris', 'Olympics', '2024', 'LIVE:', 'Wrestler', 'Aman', 'Sehrawat', '9', 'August', 'defeated', 'Puerto', "Rico's", 'Darian', 'Toi', 'Cruz', 'Men’s', 'freestyle', '57kg', 'category', 'bring', "India's", '5th', 'bronze', 'medal.', 'This', 'also', 'first', 'wrestling', 'medal', 'India', 'Paris', 'Olympics', '2024.', 'With', 'this,', "India's", 'medal', 'tally', 'rose', '6,', 'including', '5', 'bronze', 'one', 'silver.', 'Aman', 'Sehrawat', 'dominated', 'beginning', 'game', 'kept', 'lead', '6-3', 'first', 'round.', 'In', 'second', 'round,', 'Aman', 'continued', 'dominate', 'Cruz', 'exceed', 'points', '13,', 'Cruz', 'could', 'win', '5', 'points.']

# %%
import re

# %%
cleaned_txt = " ".join(cleaned_txt)
cleaned_txt
# Out:
# "Paris Olympics 2024 LIVE Updates: On 14th day Paris Olympics 2024, Wrestler Aman Sehrawat 9 August defeated Puerto Rico's Darian Toi Cruz Men’s freestyle 57kg category bring India's 5th bronze medal. This also first wrestling medal India Paris Olympics 2024. With this, India's medal tally rose 6, including 5 bronze one silver. Also, Indian athletics campaign ended men's 4x400 relay race team fell short reaching medal round finished fifth 11th overall qualification round Friday. Among details, Court Arbitration Sports 9 August said decision Vinesh Phogat's plea disqualification weight issues expected issued end Olympic Games. Earlier 8 August, Neeraj Chopra surpassed gold-medal throw Tokyo missed second consecutive top finish due exceptional performance Pakistan's Arshad Nadeem. The Indian men's hockey team gave PR Sreejesh storybook ending career. He retired two consecutive Olympic medals starting international journey India first failed qualify Games. Neeraj Chopra threw 1.87m farther Tokyo Olympic gold-winning throw, Paris, secured silver Arshad Nadeem made history Pakistan Olympic record throw 92.97m, crossing 90m final attempt claim gold. Nadeem first Pakistani win individual Olympic gold. Neeraj becomes third Indian, PV Sindhu Sushil Kumar, win individual Olympic medals two different Games. Catch LIVE updates Paris Olympics 2024 here, 09 Aug 2024, 11:25:01 PM IST Paris Olympics 2024 LIVE: Aman Sehrawat brings 5th bronze medal India, 1st wrestling Paris Olympics 2024 LIVE: Wrestler Aman Sehrawat 9 August defeated Puerto Rico's Darian Toi Cruz Men’s freestyle 57kg category bring India's 5th bronze medal. This also first wrestling medal India Paris Olympics 2024. With this, India's medal tally rose 6, including 5 bronze one silver. Aman Sehrawat dominated beginning game kept lead 6-3 first round. In second round, Aman continued dominate Cruz exceed points 13, Cruz could win 5 points."

# %%
cleaned_txt = re.sub('[0-9]' , "" , cleaned_txt) # digit removal from string
cleaned_txt = re.sub(r'\[\d+\]' , "" , cleaned_txt)  # digit removal within brackets

# %%
cleaned_txt
# Out:
# "Paris Olympics  LIVE Updates: On th day Paris Olympics , Wrestler Aman Sehrawat  August defeated Puerto Rico's Darian Toi Cruz Men’s freestyle kg category bring India's th bronze medal. This also first wrestling medal India Paris Olympics . With this, India's medal tally rose , including  bronze one silver. Also, Indian athletics campaign ended men's x relay race team fell short reaching medal round finished fifth th overall qualification round Friday. Among details, Court Arbitration Sports  August said decision Vinesh Phogat's plea disqualification weight issues expected issued end Olympic Games. Earlier  August, Neeraj Chopra surpassed gold-medal throw Tokyo missed second consecutive top finish due exceptional performance Pakistan's Arshad Nadeem. The Indian men's hockey team gave PR Sreejesh storybook ending career. He retired two consecutive Olympic medals starting international journey India first failed qualify Games. Neeraj Chopra threw .m farther Tokyo Olympic gold-winning throw, Paris, secured silver Arshad Nadeem made history Pakistan Olympic record throw .m, crossing m final attempt claim gold. Nadeem first Pakistani win individual Olympic gold. Neeraj becomes third Indian, PV Sindhu Sushil Kumar, win individual Olympic medals two different Games. Catch LIVE updates Paris Olympics  here,  Aug , :: PM IST Paris Olympics  LIVE: Aman Sehrawat brings th bronze medal India, st wrestling Paris Olympics  LIVE: Wrestler Aman Sehrawat  August defeated Puerto Rico's Darian Toi Cruz Men’s freestyle kg category bring India's th bronze medal. This also first wrestling medal India Paris Olympics . With this, India's medal tally rose , including  bronze one silver. Aman Sehrawat dominated beginning game kept lead - first round. In second round, Aman continued dominate Cruz exceed points , Cruz could win  points."

# %%
len(cleaned_txt)
# Out:
# 1840

# %%
from nltk.tokenize import word_tokenize , sent_tokenize

# %%
word_token = word_tokenize(cleaned_txt)
word_token
# Out:
# ['Paris',
#  'Olympics',
#  'LIVE',
#  'Updates',
#  ':',
#  'On',
#  'th',
#  'day',
#  'Paris',
#  'Olympics',
#  ',',
#  'Wrestler',
#  'Aman',
#  'Sehrawat',
#  'August',
#  'defeated',
#  'Puerto',
#  'Rico',
#  "'s",
#  'Darian',
#  'Toi',
#  'Cruz',
#  'Men',
#  '’',
#  's',
#  'freestyle',
#  'kg',
#  'category',
#  'bring',
#  'India',
#  "'s",
#  'th',
#  'bronze',
#  'medal',
#  '.',
#  'This',
#  'also',
#  'first',
#  'wrestling',
#  'medal',
#  'India',
#  'Paris',
#  'Olympics',
#  '.',
#  'With',
#  'this',
#  ',',
#  'India',
#  "'s",
#  'medal',
#  'tally',
#  'rose',
#  ',',
#  'including',
#  'bronze',
#  'one',
#  'silver',
#  '.',
#  'Also',
#  ',',
#  'Indian',
#  'athletics',
#  'campaign',
#  'ended',
#  'men',
#  "'s",
#  'x',
#  'relay',
#  'race',
#  'team',
#  'fell',
#  'short',
#  'reaching',
#  'medal',
#  'round',
#  'finished',
#  'fifth',
#  'th',
#  'overall',
#  'qualification',
#  'round',
#  'Friday',
#  '.',
#  'Among',
#  'details',
#  ',',
#  'Court',
#  'Arbitration',
#  'Sports',
#  'August',
#  'said',
#  'decision',
#  'Vinesh',
#  'Phogat',
#  "'s",
#  'plea',
#  'disqualification',
#  'weight',
#  'issues',
#  'expected',
#  'issued',
#  'end',
#  'Olympic',
#  'Games',
#  '.',
#  'Earlier',
#  'August',
#  ',',
#  'Neeraj',
#  'Chopra',
#  'surpassed',
#  'gold-medal',
#  'throw',
#  'Tokyo',
#  'missed',
#  'second',
#  'consecutive',
#  'top',
#  'finish',
#  'due',
#  'exceptional',
#  'performance',
#  'Pakistan',
#  "'s",
#  'Arshad',
#  'Nadeem',
#  '.',
#  'The',
#  'Indian',
#  'men',
#  "'s",
#  'hockey',
#  'team',
#  'gave',
#  'PR',
#  'Sreejesh',
#  'storybook',
#  'ending',
#  'career',
#  '.',
#  'He',
#  'retired',
#  'two',
#  'consecutive',
#  'Olympic',
#  'medals',
#  'starting',
#  'international',
#  'journey',
#  'India',
#  'first',
#  'failed',
#  'qualify',
#  'Games',
#  '.',
#  'Neeraj',
#  'Chopra',
#  'threw',
#  '.m',
#  'farther',
#  'Tokyo',
#  'Olympic',
#  'gold-winning',
#  'throw',
#  ',',
#  'Paris',
#  ',',
#  'secured',
#  'silver',
#  'Arshad',
#  'Nadeem',
#  'made',
#  'history',
#  'Pakistan',
#  'Olympic',
#  'record',
#  'throw',
#  '.m',
#  ',',
#  'crossing',
#  'm',
#  'final',
#  'attempt',
#  'claim',
#  'gold',
#  '.',
#  'Nadeem',
#  'first',
#  'Pakistani',
#  'win',
#  'individual',
#  'Olympic',
#  'gold',
#  '.',
#  'Neeraj',
#  'becomes',
#  'third',
#  'Indian',
#  ',',
#  'PV',
#  'Sindhu',
#  'Sushil',
#  'Kumar',
#  ',',
#  'win',
#  'individual',
#  'Olympic',
#  'medals',
#  'two',
#  'different',
#  'Games',
#  '.',
#  'Catch',
#  'LIVE',
#  'updates',
#  'Paris',
#  'Olympics',
#  'here',
#  ',',
#  'Aug',
#  ',',
#  ':',
#  ':',
#  'PM',
#  'IST',
#  'Paris',
#  'Olympics',
#  'LIVE',
#  ':',
#  'Aman',
#  'Sehrawat',
#  'brings',
#  'th',
#  'bronze',
#  'medal',
#  'India',
#  ',',
#  'st',
#  'wrestling',
#  'Paris',
#  'Olympics',
#  'LIVE',
#  ':',
#  'Wrestler',
#  'Aman',
#  'Sehrawat',
#  'August',
#  'defeated',
#  'Puerto',
#  'Rico',
#  "'s",
#  'Darian',
#  'Toi',
#  'Cruz',
#  'Men',
#  '’',
#  's',
#  'freestyle',
#  'kg',
#  'category',
#  'bring',
#  'India',
#  "'s",
#  'th',
#  'bronze',
#  'medal',
#  '.',
#  'This',
#  'also',
#  'first',
#  'wrestling',
#  'medal',
#  'India',
#  'Paris',
#  'Olympics',
#  '.',
#  'With',
#  'this',
#  ',',
#  'India',
#  "'s",
#  'medal',
#  'tally',
#  'rose',
#  ',',
#  'including',
#  'bronze',
#  'one',
#  'silver',
#  '.',
#  'Aman',
#  'Sehrawat',
#  'dominated',
#  'beginning',
#  'game',
#  'kept',
#  'lead',
#  '-',
#  'first',
#  'round',
#  '.',
#  'In',
#  'second',
#  'round',
#  ',',
#  'Aman',
#  'continued',
#  'dominate',
#  'Cruz',
#  'exceed',
#  'points',
#  ',',
#  'Cruz',
#  'could',
#  'win',
#  'points',
#  '.']

# %%
from nltk.stem import PorterStemmer

# %%
p = PorterStemmer()
porter_stemmer = [p.stem(word) for word in word_token]
porter_stemmer
# Out:
# ['pari',
#  'olymp',
#  'live',
#  'updat',
#  ':',
#  'on',
#  'th',
#  'day',
#  'pari',
#  'olymp',
#  ',',
#  'wrestler',
#  'aman',
#  'sehrawat',
#  'august',
#  'defeat',
#  'puerto',
#  'rico',
#  "'s",
#  'darian',
#  'toi',
#  'cruz',
#  'men',
#  '’',
#  's',
#  'freestyl',
#  'kg',
#  'categori',
#  'bring',
#  'india',
#  "'s",
#  'th',
#  'bronz',
#  'medal',
#  '.',
#  'thi',
#  'also',
#  'first',
#  'wrestl',
#  'medal',
#  'india',
#  'pari',
#  'olymp',
#  '.',
#  'with',
#  'thi',
#  ',',
#  'india',
#  "'s",
#  'medal',
#  'talli',
#  'rose',
#  ',',
#  'includ',
#  'bronz',
#  'one',
#  'silver',
#  '.',
#  'also',
#  ',',
#  'indian',
#  'athlet',
#  'campaign',
#  'end',
#  'men',
#  "'s",
#  'x',
#  'relay',
#  'race',
#  'team',
#  'fell',
#  'short',
#  'reach',
#  'medal',
#  'round',
#  'finish',
#  'fifth',
#  'th',
#  'overal',
#  'qualif',
#  'round',
#  'friday',
#  '.',
#  'among',
#  'detail',
#  ',',
#  'court',
#  'arbitr',
#  'sport',
#  'august',
#  'said',
#  'decis',
#  'vinesh',
#  'phogat',
#  "'s",
#  'plea',
#  'disqualif',
#  'weight',
#  'issu',
#  'expect',
#  'issu',
#  'end',
#  'olymp',
#  'game',
#  '.',
#  'earlier',
#  'august',
#  ',',
#  'neeraj',
#  'chopra',
#  'surpass',
#  'gold-med',
#  'throw',
#  'tokyo',
#  'miss',
#  'second',
#  'consecut',
#  'top',
#  'finish',
#  'due',
#  'except',
#  'perform',
#  'pakistan',
#  "'s",
#  'arshad',
#  'nadeem',
#  '.',
#  'the',
#  'indian',
#  'men',
#  "'s",
#  'hockey',
#  'team',
#  'gave',
#  'pr',
#  'sreejesh',
#  'storybook',
#  'end',
#  'career',
#  '.',
#  'he',
#  'retir',
#  'two',
#  'consecut',
#  'olymp',
#  'medal',
#  'start',
#  'intern',
#  'journey',
#  'india',
#  'first',
#  'fail',
#  'qualifi',
#  'game',
#  '.',
#  'neeraj',
#  'chopra',
#  'threw',
#  '.m',
#  'farther',
#  'tokyo',
#  'olymp',
#  'gold-win',
#  'throw',
#  ',',
#  'pari',
#  ',',
#  'secur',
#  'silver',
#  'arshad',
#  'nadeem',
#  'made',
#  'histori',
#  'pakistan',
#  'olymp',
#  'record',
#  'throw',
#  '.m',
#  ',',
#  'cross',
#  'm',
#  'final',
#  'attempt',
#  'claim',
#  'gold',
#  '.',
#  'nadeem',
#  'first',
#  'pakistani',
#  'win',
#  'individu',
#  'olymp',
#  'gold',
#  '.',
#  'neeraj',
#  'becom',
#  'third',
#  'indian',
#  ',',
#  'pv',
#  'sindhu',
#  'sushil',
#  'kumar',
#  ',',
#  'win',
#  'individu',
#  'olymp',
#  'medal',
#  'two',
#  'differ',
#  'game',
#  '.',
#  'catch',
#  'live',
#  'updat',
#  'pari',
#  'olymp',
#  'here',
#  ',',
#  'aug',
#  ',',
#  ':',
#  ':',
#  'pm',
#  'ist',
#  'pari',
#  'olymp',
#  'live',
#  ':',
#  'aman',
#  'sehrawat',
#  'bring',
#  'th',
#  'bronz',
#  'medal',
#  'india',
#  ',',
#  'st',
#  'wrestl',
#  'pari',
#  'olymp',
#  'live',
#  ':',
#  'wrestler',
#  'aman',
#  'sehrawat',
#  'august',
#  'defeat',
#  'puerto',
#  'rico',
#  "'s",
#  'darian',
#  'toi',
#  'cruz',
#  'men',
#  '’',
#  's',
#  'freestyl',
#  'kg',
#  'categori',
#  'bring',
#  'india',
#  "'s",
#  'th',
#  'bronz',
#  'medal',
#  '.',
#  'thi',
#  'also',
#  'first',
#  'wrestl',
#  'medal',
#  'india',
#  'pari',
#  'olymp',
#  '.',
#  'with',
#  'thi',
#  ',',
#  'india',
#  "'s",
#  'medal',
#  'talli',
#  'rose',
#  ',',
#  'includ',
#  'bronz',
#  'one',
#  'silver',
#  '.',
#  'aman',
#  'sehrawat',
#  'domin',
#  'begin',
#  'game',
#  'kept',
#  'lead',
#  '-',
#  'first',
#  'round',
#  '.',
#  'in',
#  'second',
#  'round',
#  ',',
#  'aman',
#  'continu',
#  'domin',
#  'cruz',
#  'exceed',
#  'point',
#  ',',
#  'cruz',
#  'could',
#  'win',
#  'point',
#  '.']

# %%
cleaned_txt = " ".join(porter_stemmer)
cleaned_txt
# Out:
# "pari olymp live updat : on th day pari olymp , wrestler aman sehrawat august defeat puerto rico 's darian toi cruz men ’ s freestyl kg categori bring india 's th bronz medal . thi also first wrestl medal india pari olymp . with thi , india 's medal talli rose , includ bronz one silver . also , indian athlet campaign end men 's x relay race team fell short reach medal round finish fifth th overal qualif round friday . among detail , court arbitr sport august said decis vinesh phogat 's plea disqualif weight issu expect issu end olymp game . earlier august , neeraj chopra surpass gold-med throw tokyo miss second consecut top finish due except perform pakistan 's arshad nadeem . the indian men 's hockey team gave pr sreejesh storybook end career . he retir two consecut olymp medal start intern journey india first fail qualifi game . neeraj chopra threw .m farther tokyo olymp gold-win throw , pari , secur silver arshad nadeem made histori pakistan olymp record throw .m , cross m final attempt claim gold . nadeem first pakistani win individu olymp gold . neeraj becom third indian , pv sindhu sushil kumar , win individu olymp medal two differ game . catch live updat pari olymp here , aug , : : pm ist pari olymp live : aman sehrawat bring th bronz medal india , st wrestl pari olymp live : wrestler aman sehrawat august defeat puerto rico 's darian toi cruz men ’ s freestyl kg categori bring india 's th bronz medal . thi also first wrestl medal india pari olymp . with thi , india 's medal talli rose , includ bronz one silver . aman sehrawat domin begin game kept lead - first round . in second round , aman continu domin cruz exceed point , cruz could win point ."

# %%
sent_token = sent_tokenize(cleaned_txt)
sent_token
# Out:
# ["pari olymp live updat : on th day pari olymp , wrestler aman sehrawat august defeat puerto rico 's darian toi cruz men ’ s freestyl kg categori bring india 's th bronz medal .",
#  'thi also first wrestl medal india pari olymp .',
#  "with thi , india 's medal talli rose , includ bronz one silver .",
#  "also , indian athlet campaign end men 's x relay race team fell short reach medal round finish fifth th overal qualif round friday .",
#  "among detail , court arbitr sport august said decis vinesh phogat 's plea disqualif weight issu expect issu end olymp game .",
#  "earlier august , neeraj chopra surpass gold-med throw tokyo miss second consecut top finish due except perform pakistan 's arshad nadeem .",
#  "the indian men 's hockey team gave pr sreejesh storybook end career .",
#  'he retir two consecut olymp medal start intern journey india first fail qualifi game .',
#  'neeraj chopra threw .m farther tokyo olymp gold-win throw , pari , secur silver arshad nadeem made histori pakistan olymp record throw .m , cross m final attempt claim gold .',
#  'nadeem first pakistani win individu olymp gold .',
#  'neeraj becom third indian , pv sindhu sushil kumar , win individu olymp medal two differ game .',
#  "catch live updat pari olymp here , aug , : : pm ist pari olymp live : aman sehrawat bring th bronz medal india , st wrestl pari olymp live : wrestler aman sehrawat august defeat puerto rico 's darian toi cruz men ’ s freestyl kg categori bring india 's th bronz medal .",
#  'thi also first wrestl medal india pari olymp .',
#  "with thi , india 's medal talli rose , includ bronz one silver .",
#  'aman sehrawat domin begin game kept lead - first round .',
#  'in second round , aman continu domin cruz exceed point , cruz could win point .']

# %%
from textblob import TextBlob

sentence_list = []
polarity_act = []
polarity_list =[]

for i in sent_token:
    sentence = i
    blob = TextBlob(sentence)  # Create a TextBlob object
    polarity = blob.sentiment.polarity  # Get the polarity score 
    sentence_list.append(sentence)
    polarity_act.append(polarity)
    if polarity>0:
        print(f"Sentence: {sentence}")
        print(f"Polarity: {polarity}")
        print(f"Positive:{1}")
        polarity_list.append(1)
        print("\t")
            
    elif polarity==0:
        print(f"Sentence: {sentence}")
        print(f"Polarity: {polarity}")
        print(f"Neutral :{0}")
        polarity_list.append(0)
        print("\t")
    else:
        print(f"Sentence: {sentence}")
        print(f"Polarity: {polarity}")
        print(f"Negative: {-1}")
        polarity_list.append(-1)
        print("\t")
# Out:
# Sentence: pari olymp live updat : on th day pari olymp , wrestler aman sehrawat august defeat puerto rico 's darian toi cruz men ’ s freestyl kg categori bring india 's th bronz medal .
# Polarity: 0.13636363636363635
# Positive:1
#
# Sentence: thi also first wrestl medal india pari olymp .
# Polarity: 0.25
# Positive:1
#
# Sentence: with thi , india 's medal talli rose , includ bronz one silver .
# Polarity: 0.6
# Positive:1
#
# Sentence: also , indian athlet campaign end men 's x relay race team fell short reach medal round finish fifth th overal qualif round friday .
# Polarity: -0.13333333333333333
# Negative: -1
#
# Sentence: among detail , court arbitr sport august said decis vinesh phogat 's plea disqualif weight issu expect issu end olymp game .
# Polarity: -0.4
# Negative: -1
#
# Sentence: earlier august , neeraj chopra surpass gold-med throw tokyo miss second consecut top finish due except perform pakistan 's arshad nadeem .
# Polarity: 0.09375
# Positive:1
#
# Sentence: the indian men 's hockey team gave pr sreejesh storybook end career .
# Polarity: 0.0
# Neutral :0
#
# Sentence: he retir two consecut olymp medal start intern journey india first fail qualifi game .
# Polarity: -0.21666666666666667
# Negative: -1
#
# Sentence: neeraj chopra threw .m farther tokyo olymp gold-win throw , pari , secur silver arshad nadeem made histori pakistan olymp record throw .m , cross m final attempt claim gold .
# Polarity: 0.0
# Neutral :0
#
# Sentence: nadeem first pakistani win individu olymp gold .
# Polarity: 0.525
# Positive:1
#
# Sentence: neeraj becom third indian , pv sindhu sushil kumar , win individu olymp medal two differ game .
# Polarity: 0.13333333333333333
# Positive:1
#
# Sentence: catch live updat pari olymp here , aug , : : pm ist pari olymp live : aman sehrawat bring th bronz medal india , st wrestl pari olymp live : wrestler aman sehrawat august defeat puerto rico 's darian toi cruz men ’ s freestyl kg categori bring india 's th bronz medal .
# Polarity: 0.13636363636363635
# Positive:1
#
# Sentence: thi also first wrestl medal india pari olymp .
# Polarity: 0.25
# Positive:1
#
# Sentence: with thi , india 's medal talli rose , includ bronz one silver .
# Polarity: 0.6
# Positive:1
#
# Sentence: aman sehrawat domin begin game kept lead - first round .
# Polarity: -0.11666666666666668
# Negative: -1
#
# Sentence: in second round , aman continu domin cruz exceed point , cruz could win point .
# Polarity: 0.20000000000000004
# Positive:1

# %%
print(len(sentence_list))
print(len(polarity_act))
print(len(polarity_list))
# Out:
# 16
# 16
# 16

# %%
polar_data = pd.DataFrame({
    "Sentence" : sentence_list, 
    "Polarity_val" : polarity_act,
    "Polarity_score" : polarity_list
})

# %%
polar_data.to_csv("polar_data.csv")

# %%
dataset = pd.read_csv("polar_data.csv")

# %%
dataset.drop(dataset.columns[0] , axis=1 ,inplace=True)

# %%
dataset.head(3)
# Out:
#                                             Sentence  Polarity_val  \
# 0  pari olymp live updat : on th day pari olymp ,...      0.136364
# 1     thi also first wrestl medal india pari olymp .      0.250000
# 2  with thi , india 's medal talli rose , includ ...      0.600000
#
#    Polarity_score
# 0               1
# 1               1
# 2               1

# %%
x=dataset[["Polarity_val"]]
y=dataset["Polarity_score"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(data=dataset , x="Polarity_val", y="Polarity_score" , hue="Polarity_score")
# Out:
# <Axes: xlabel='Polarity_val', ylabel='Polarity_score'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size=.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train , y_train) , lr.score(x_test , y_test)
# Out:
# (0.6666666666666666, 0.75)

# %%
lr.predict()
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 lr.predict(0.1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:332, in LinearClassifierMixin.decision_function(self, X)
#     329 check_is_fitted(self)
#     330 xp, _ = get_namespace(X)
# --> 332 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     333 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     334 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009 if ensure_2d:
#    1010     # If input is scalar raise error
#    1011     if array.ndim == 0:
# -> 1012         raise ValueError(
#    1013             "Expected 2D array, got scalar array instead:\narray={}.\n"
#    1014             "Reshape your data either using array.reshape(-1, 1) if "
#    1015             "your data has a single feature or array.reshape(1, -1) "
#    1016             "if it contains a single sample.".format(array)
#    1017         )
#    1018     # If input is 1D raise error
#    1019     if array.ndim == 1:
#    1020         # If input is a Series-like object (eg. pandas Series or polars Series)
#
# ValueError: Expected 2D array, got scalar array instead:
# array=0.1.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
